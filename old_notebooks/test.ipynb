# %%
def update_cell(results, x_val, y_val, mask):
    #     global cells_in_circle  # Declare cells_in_circle as global if it's defined outside this function

#     if len(results) > 1:
#         raise Exception("matched multiple cells")
#     elif len(results) == 1:
#         if ((results.iloc[0]["grid_loc_x"] != x_val or results.iloc[0]["grid_loc_y"] != y_val) and
#             (results.iloc[0]["grid_loc_x"] is not None and results.iloc[0]["grid_loc_y"] is not None)):
#             raise Exception("iterating over existing cell")
#         cells_in_circle.loc[mask, "grid_loc_x"] = x_val
#         cells_in_circle.loc[mask, "grid_loc_y"] = y_val
#     elif len(results) == 0:
#         return False

#     return True

# def scan_longitude(initial_lon, y_lat, y_val, increment):
#     x_lon = initial_lon
#     x_val = 0
#     x_search = True
#     while x_search:
#         x_lon += increment * x_len
#         point = Point(x_lon, y_lat)
#         x_val += increment
#         mask = point.within(cells_in_circle["geometry"])
#         results = cells_in_circle[mask]
#         x_search = update_cell(results, x_val, y_val, mask)
#         print(x_val, y_val)

# def scan_latitude(initial_lat, increment):
#     y_lat = initial_lat
#     y_val = 0
#     y_search = True
#     while y_search:
#         y_lat += increment * y_len
#         point = Point(x_lon, y_lat)
#         y_val += increment
#         mask = point.within(cells_in_circle["geometry"])
#         results = cells_in_circle[mask]
#         y_search = update_cell(results, 0, y_val, mask)

#         # Scan longitude in both directions
#         scan_longitude(x_lon, y_lat, y_val, -1)  # Scan to the left
#         scan_longitude(x_lon, y_lat, y_val, 1)   # Scan to the right

# x_lon = centre_point_local_crs.x
# y_lat = centre_point_local_crs.y

# # Scan latitude in both directions
# scan_latitude(y_lat, 1)  # Scan upwards
# scan_latitude(y_lat, -1) # Scan downwards
